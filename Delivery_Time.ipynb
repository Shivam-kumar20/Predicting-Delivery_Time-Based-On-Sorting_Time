# %% [markdown]
# ### Delivery Time Model

# %%
# importing Libraries

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# Reading Dataset

path = 'C:/Users/shivam.kumar/Videos/CodeWithHarry/18 Nov Assignment/Project - 1&2_ Simple_Reg/delivery_time.csv'
df= pd.read_csv(path,encoding = 'utf-8')
data=df.copy()  # making the copy of the dataset

# %%
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
df.sort_values(by='Sorting Time')
# Out:
#     Delivery Time  Sorting Time
# 18           8.00             2
# 7            9.50             3
# 13          11.50             3
# 14          12.03             3
# 1           13.50             4
# 15          14.88             4
# 11          10.75             4
# 20          21.50             5
# 2           19.75             6
# 5           15.35             6
# 16          13.75             6
# 17          18.11             7
# 6           19.00             7
# 19          17.83             7
# 12          16.68             7
# 10          19.83             8
# 3           24.00             9
# 9           18.75             9
# 8           17.90            10
# 4           29.00            10
# 0           21.00            10

# %%
data.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
# machine learing model - Delivery_time prediction model with the use of sorting_time

data.rename(columns ={'Delivery Time':'Delivery_Time',
                     'Sorting Time':'Sorting_Time'},inplace =True)

# we are making a dataset model where we are pedicting the delivery_time[y] using sorting_time[x]

x=data['Sorting_Time'].values.reshape(-1,1)
y=data['Delivery_Time'].values.reshape(-1,1)

# %%
# Training the model
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state =1)

lr=LinearRegression()

fit_model =lr.fit(x_train,y_train)

pre = lr.predict(x_test)
print(f'The actual value of model is {y_test} and predicted value is {pre} ')

score = r2_score(y_test,pre)
print(score)
# note : prediction value m hamesha x_test jyga jiski value vo self predict krega and usko compare krna hai with Y_test
# Out:
# The actual value of model is [[14.88]
#  [19.83]
#  [24.  ]
#  [ 8.  ]
#  [18.11]] and predicted value is [[13.29502632]
#  [19.41386842]
#  [20.94357895]
#  [10.23560526]
#  [17.88415789]]
# 0.881193344590806

# %%
data.plot(x='Sorting_Time',y='Delivery_Time',kind='barh')
data.plot(x='Sorting_Time',y='Delivery_Time',kind='bar')
data.plot(x='Sorting_Time',y='Delivery_Time',kind='scatter')
# Out:
# <Axes: xlabel='Sorting_Time', ylabel='Delivery_Time'>

# %%
# from the above graphs it is clearly visile - as the sorting time increases the delivery time also increases
